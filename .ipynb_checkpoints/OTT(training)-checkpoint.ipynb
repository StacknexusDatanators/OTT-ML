# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
b2b_df = pd.read_csv("data/B2B_Partner.csv")
complaints_df = pd.read_csv("data/complaints.csv")
player_df = pd.read_csv("data/Player_data.csv")
billing_df = pd.read_csv("data/Billing.csv")
contracts_df = pd.read_csv("data/contracts.csv")
users_df = pd.read_csv("data/User_subscription.csv")

# %%
player_df.head()
# Out:
#   EventType         SessionStart            Timezone  Subscribed Platform  \
# 0     pause  2021-03-28 12:54:12       Africa/Douala        True   FireTV
# 1      stop  2021-01-02 04:12:17  America/Montevideo        True  Browser
# 2      play  2021-07-06 17:12:01       Africa/Harare       False  Android
# 3      skip  2021-09-29 23:07:07      America/Nassau       False   FireTV
# 4      play  2021-05-10 01:51:44     Africa/Blantyre       False      iOS
#
#   PartnerId  ApplicationVersion     Location       Hardware operatingSystem  \
# 0   hotstar                 2.7   Bhimavaram         FireTV         Android
# 1   hotstar                 2.5     Phagwara      PC/Laptop           MacOS
# 2   hotstar                 4.9       Ranchi  Android Phone         Android
# 3   hotstar                 4.0     Vadodara         FireTV         Android
# 4   hotstar                 1.9  Gandhinagar         iPhone             iOS
#
#    ... DeliveryProtocol Playing_rate  StartingBitrate Video_resolution  \
# 0  ...       Cloudfront          NaN              7.6               2K
# 1  ...       Cloudfront          NaN              5.5             480p
# 2  ...       Cloudfront          NaN              8.7             720p
# 3  ...           Akamai          NaN              9.4             480p
# 4  ...           Akamai          NaN              9.9             720p
#
#    Start_position  End_position        UserId                 DeviceId  \
# 0           00:25         00:57  jeffreylewis  407ta-N84G2-9o5LH-DP8Qe
# 1           00:29         00:41     jessica41  856cp-i25o9-9u3YO-JL8YY
# 2           00:26         00:48      justin83  962gJ-n52j8-8F9Jl-Gy3UV
# 3           01:22         02:00     michael21  347Vt-F15u7-6W3zh-Ki8BY
# 4           00:42         02:35      parker98  464Mg-D08Q1-6B0iD-ve1mH
#
#   Video_position Duration
# 0          00:56   1848.0
# 1          00:34    307.0
# 2          00:38    730.0
# 3          01:59   2188.0
# 4          01:36   3239.0
#
# [5 rows x 29 columns]

# %%
users_df.head()
# Out:
#       profile_ID Contact_type         DOB                   Email First_Name  \
# 0       rsanchez        Email   6/10/2005  ldixson3h@engadget.com      Leese
# 1       karina10        Email   1/12/2005    rearngy40@sphinn.com    Rubetta
# 2     sethconrad        Email  10/30/1992    tbecom72@spotify.com       Tait
# 3        ewilson        Email   8/14/2015    elavalde9g@google.ru    Eugenia
# 4  evanvelasquez        Email   5/25/1992      dmencib1@cisco.com      Devan
#
#    Gender Mobile_Number  Pack_ID  Start_Date    Status Upgradable  \
# 0  Female  391-447-5117   432281  10/28/2021  INACTIVE        YES
# 1  Female  777-570-1291   432300   2/10/2021  INACTIVE         NO
# 2    Male  901-892-5768   432410  10/30/2022    ACTIVE        YES
# 3  Female  711-627-9420   432496   1/14/2022    ACTIVE         NO
# 4  Female  902-541-3157   432553   1/21/2022  INACTIVE        YES
#
#   Validity_End Country State  customerID Zipcode
# 0    12/5/2022   India   Goa  2546-KZAAT  665 33
# 1   11/22/2022   India   Goa  2371-KFUOG  111721
# 2   11/10/2022   India   Goa  0188-GWFLE     NaN
# 3   12/27/2022   India   Goa  0289-IVARM     NaN
# 4    11/9/2022   India   Goa  7672-VFMXZ     NaN

# %%
player_df.to_csv("player_df.csv", index = False)

# %%
def get_most_common_dev(devlist):
    c = Counter(devlist)
    return c.most_common(1)[0][0]

# %%
agg_dict = {
    "Duration":"mean",
    "DeviceId": pd.Series.nunique,
    "Hardware": get_most_common_dev,
    
}


player_agged = player_df.groupby("UserId").agg(agg_dict)

# %%
player_agged.reset_index(inplace = True)

# %%
player_agged.rename(columns = {"Duration":"avg_dur", 
                               "DeviceId":"num_devs", 
                               "Hardware":"freq_used_dev"}, inplace = True)

# %%
users_players_joined = users_df.merge(player_agged, left_on="profile_ID", right_on = "UserId", how = "left")

# %%
agg_dict = {
    "partner id":pd.Series.nunique,
    "device id": pd.Series.nunique,
    "device type": get_most_common_dev,
    
}


b2b_agged = b2b_df.groupby("customerID").agg(agg_dict)

# %%
b2b_agged.reset_index(inplace = True)

# %%
b2b_agged.rename(columns = {"partner id":"part_id", 
                            "deviceId":"num_devs", 
                            "device type":"freq_used_type"}, inplace = True)

# %%
users_b2b_joined = users_df.merge(b2b_agged, on = "customerID", how = "left")

# %%
users_b2b_joined
# Out:
#         profile_ID Contact_type         DOB                        Email  \
# 0         rsanchez        Email   6/10/2005       ldixson3h@engadget.com
# 1         karina10        Email   1/12/2005         rearngy40@sphinn.com
# 2       sethconrad        Email  10/30/1992         tbecom72@spotify.com
# 3          ewilson        Email   8/14/2015         elavalde9g@google.ru
# 4    evanvelasquez        Email   5/25/1992           dmencib1@cisco.com
# ..             ...          ...         ...                          ...
# 995       brandili     WhatsApp  12/14/2021              mcokee0@psu.edu
# 996      davidlowe     WhatsApp    4/1/1993        ctothex@google.com.hk
# 997   carrierivera     WhatsApp   9/30/2002       bmacevillyh3@prlog.org
# 998   ronniecoffey     WhatsApp   8/29/2002         lberrowhy@smh.com.au
# 999     kathleen63     WhatsApp   5/28/1989  vmogienh@huffingtonpost.com
#
#     First_Name       Gender Mobile_Number  Pack_ID  Start_Date    Status  \
# 0        Leese       Female  391-447-5117   432281  10/28/2021  INACTIVE
# 1      Rubetta       Female  777-570-1291   432300   2/10/2021  INACTIVE
# 2         Tait         Male  901-892-5768   432410  10/30/2022    ACTIVE
# 3      Eugenia       Female  711-627-9420   432496   1/14/2022    ACTIVE
# 4        Devan       Female  902-541-3157   432553   1/21/2022  INACTIVE
# ..         ...          ...           ...      ...         ...       ...
# 995   Maryjane       Female  755-848-1351   432660   3/22/2022  INACTIVE
# 996       Chic         Male  472-131-0900   432693   9/25/2021  INACTIVE
# 997       Bili       Female  568-875-8493   432771  11/24/2021  INACTIVE
# 998      Lilli       Female  380-420-0034   432802   1/21/2022    ACTIVE
# 999     Verney  Genderqueer  192-265-1461   433001   7/24/2021    ACTIVE
#
#     Upgradable Validity_End Country              State  customerID Zipcode  \
# 0          YES    12/5/2022   India                Goa  2546-KZAAT  665 33
# 1           NO   11/22/2022   India                Goa  2371-KFUOG  111721
# 2          YES   11/10/2022   India                Goa  0188-GWFLE     NaN
# 3           NO   12/27/2022   India                Goa  0289-IVARM     NaN
# 4          YES    11/9/2022   India                Goa  7672-VFMXZ     NaN
# ..         ...          ...     ...                ...         ...     ...
# 995         NO   12/26/2022   India  Arunachal Pradesh  7361-YPXFS     NaN
# 996        YES   11/14/2022   India  Arunachal Pradesh  3466-BYAVD     NaN
# 997        YES    12/3/2022   India  Arunachal Pradesh  5652-MSDEY    6340
# 998         NO   12/16/2022   India  Arunachal Pradesh  9970-QBCDA     NaN
# 999         NO   12/11/2022   India  Arunachal Pradesh  6513-EECDB     NaN
#
#      part_id  device id freq_used_type
# 0          1          1             tv
# 1          1          1         mobile
# 2          1          1             tv
# 3          1          1         mobile
# 4          1          1         mobile
# ..       ...        ...            ...
# 995        1          1         mobile
# 996        1          1         mobile
# 997        1          1         mobile
# 998        1          1         laptop
# 999        1          1         mobile
#
# [1000 rows x 19 columns]

# %%
users_players_joined
# Out:
#         profile_ID Contact_type         DOB                        Email  \
# 0         rsanchez        Email   6/10/2005       ldixson3h@engadget.com
# 1         karina10        Email   1/12/2005         rearngy40@sphinn.com
# 2       sethconrad        Email  10/30/1992         tbecom72@spotify.com
# 3          ewilson        Email   8/14/2015         elavalde9g@google.ru
# 4    evanvelasquez        Email   5/25/1992           dmencib1@cisco.com
# ..             ...          ...         ...                          ...
# 995       brandili     WhatsApp  12/14/2021              mcokee0@psu.edu
# 996      davidlowe     WhatsApp    4/1/1993        ctothex@google.com.hk
# 997   carrierivera     WhatsApp   9/30/2002       bmacevillyh3@prlog.org
# 998   ronniecoffey     WhatsApp   8/29/2002         lberrowhy@smh.com.au
# 999     kathleen63     WhatsApp   5/28/1989  vmogienh@huffingtonpost.com
#
#     First_Name       Gender Mobile_Number  Pack_ID  Start_Date    Status  \
# 0        Leese       Female  391-447-5117   432281  10/28/2021  INACTIVE
# 1      Rubetta       Female  777-570-1291   432300   2/10/2021  INACTIVE
# 2         Tait         Male  901-892-5768   432410  10/30/2022    ACTIVE
# 3      Eugenia       Female  711-627-9420   432496   1/14/2022    ACTIVE
# 4        Devan       Female  902-541-3157   432553   1/21/2022  INACTIVE
# ..         ...          ...           ...      ...         ...       ...
# 995   Maryjane       Female  755-848-1351   432660   3/22/2022  INACTIVE
# 996       Chic         Male  472-131-0900   432693   9/25/2021  INACTIVE
# 997       Bili       Female  568-875-8493   432771  11/24/2021  INACTIVE
# 998      Lilli       Female  380-420-0034   432802   1/21/2022    ACTIVE
# 999     Verney  Genderqueer  192-265-1461   433001   7/24/2021    ACTIVE
#
#     Upgradable Validity_End Country              State  customerID Zipcode  \
# 0          YES    12/5/2022   India                Goa  2546-KZAAT  665 33
# 1           NO   11/22/2022   India                Goa  2371-KFUOG  111721
# 2          YES   11/10/2022   India                Goa  0188-GWFLE     NaN
# 3           NO   12/27/2022   India                Goa  0289-IVARM     NaN
# 4          YES    11/9/2022   India                Goa  7672-VFMXZ     NaN
# ..         ...          ...     ...                ...         ...     ...
# 995         NO   12/26/2022   India  Arunachal Pradesh  7361-YPXFS     NaN
# 996        YES   11/14/2022   India  Arunachal Pradesh  3466-BYAVD     NaN
# 997        YES    12/3/2022   India  Arunachal Pradesh  5652-MSDEY    6340
# 998         NO   12/16/2022   India  Arunachal Pradesh  9970-QBCDA     NaN
# 999         NO   12/11/2022   India  Arunachal Pradesh  6513-EECDB     NaN
#
#             UserId      avg_dur  num_devs  freq_used_dev
# 0         rsanchez  1512.277778        18  Android Phone
# 1         karina10  1329.500000         8           iPad
# 2       sethconrad  1478.166667        18      PC/Laptop
# 3          ewilson  1118.133333        15      PC/Laptop
# 4    evanvelasquez  1557.428571        21         FireTV
# ..             ...          ...       ...            ...
# 995       brandili  1266.307692        13      PC/Laptop
# 996      davidlowe  1199.000000        18         FireTV
# 997   carrierivera  1482.000000        17         FireTV
# 998   ronniecoffey  1518.000000        30      PC/Laptop
# 999     kathleen63   520.200000        15         FireTV
#
# [1000 rows x 20 columns]

# %%
billing_df
# Out:
#     Customer Id  Billing Id Subscription Type  Billing Type   \
# 0    2546-KZAAT      432156          12 Months         Paytm
# 1    2371-KFUOG      432157           3 Months    NetBanking
# 2    0188-GWFLE      432158           6 Months    NetBanking
# 3    0289-IVARM      432159          12 Months         Paytm
# 4    7672-VFMXZ      432160          12 Months         Paytm
# ..          ...         ...                ...           ...
# 995  7361-YPXFS      433151          12 Months         Paytm
# 996  3466-BYAVD      433152          12 Months         Paytm
# 997  5652-MSDEY      433153          12 Months         Paytm
# 998  9970-QBCDA      433154          12 Months         Paytm
# 999  6513-EECDB      433155          12 Months         Paytm
#
#     Customer Longevity
# 0              4 Years
# 1              2 Years
# 2              3 Years
# 3              4 Years
# 4              4 Years
# ..                 ...
# 995            4 Years
# 996            4 Years
# 997            4 Years
# 998            4 Years
# 999            4 Years
#
# [1000 rows x 5 columns]

# %%
billing_df["Customer Id"] = users_players_joined["customerID"]

# %%
users_training = users_players_joined.merge(billing_df, left_on = 'customerID', right_on = "Customer Id", how = 'left')

# %%
complaints_df
# Out:
#                                    IssueType deviceType   IssueTime  \
# 0                   Security and anti-piracy    Desktop  27-03-2022
# 1                   Security and anti-piracy    Tablets  10-05-2022
# 2                     Multiple user accounts         TV  27-07-2022
# 3                           Playback Quality    Desktop  26-07-2022
# 4    Functionalities and features of the app    Desktop  03-02-2022
# ..                                       ...        ...         ...
# 995                         Playback Quality         TV  12-10-2022
# 996      Response Time in different networks     Laptop  27-10-2022
# 997                          Offline content     Mobile  10-05-2022
# 998      Response Time in different networks     Laptop  04-06-2022
# 999      Response Time in different networks    Tablets  08-03-2022
#
#                                           IssueDetails  mobileNumber  \
# 0    potenti nullam porttitor lacus at turpis donec...    4016190347
# 1    vel accumsan tellus nisi eu orci mauris lacini...     146998510
# 2    in sagittis dui vel nisl duis ac nibh fusce la...    9928344523
# 3    ligula vehicula consequat morbi a ipsum intege...     221503226
# 4    augue a suscipit nulla elit ac nulla sed vel e...    9051530633
# ..                                                 ...           ...
# 995  non quam nec dui luctus rutrum nulla tellus in...    4226896424
# 996  ac nulla sed vel enim sit amet nunc viverra da...    3026274461
# 997  et magnis dis parturient montes nascetur ridic...     272967270
# 998  facilisi cras non velit nec nisi vulputate non...    1751366189
# 999  malesuada in imperdiet et commodo vulputate ju...    6286617744
#
#                         emailId        mode         cdn  \
# 0              ggrono0@yale.edu       Email  Cloudfront
# 1              acann1@vimeo.com  Phone Call  Cloudfront
# 2         fdizlie2@mashable.com  Phone Call  Cloudfront
# 3                eloges3@hp.com  Phone Call  Cloudfront
# 4     gmcdermott4@bloomberg.com        Chat      Akamai
# ..                          ...         ...         ...
# 995  kphoebern@wunderground.com       Email      Akamai
# 996       lgeorgeotro@blogs.com  Phone Call  Cloudfront
# 997       mharfleetrp@google.it       Email  Cloudfront
# 998        snottramrq@exblog.jp       Email      Akamai
# 999         wcainrr@cornell.edu       Email      Akamai
#
#                            userIdentifier                     deviceDetails  \
# 0    33824779-a665-4ba5-b3d0-0de8228e107d                               iOS
# 1    f057f978-2bcf-4280-a52b-9045aed4f0fa                              tvOS
# 2    7e20a079-a408-4f3e-b955-aa4bf1a57920                           Android
# 3    9f6559ce-efb1-4008-a516-eb71010029df                        Android TV
# 4    e96a1649-4bf3-4533-a696-d304b2882ca5                              Roku
# ..                                    ...                               ...
# 995  1d63557f-57e3-487d-a6a1-c540654600be                        Android TV
# 996  528450d5-63ed-4d8b-99f2-37c8097ff862                              Roku
# 997  8bf95aef-a255-4996-af58-5a1d8ad618bb                    Amazon Fire TV
# 998  0a29b7db-a8bf-4637-a3e5-d15f48d099c8  Universal Windows Platform (UWP)
# 999  ef7b836e-4e26-42aa-9543-3059a112e3f6                  Samsung Tizen TV
#
#                       OSDetails            platform            appVersion  \
# 0          iOS Min version 12.6          YouTube TV  macOS Ventura 13.0.1
# 1                     tvOS 11.0             BigFlix            Xcode 14.1
# 2                   Android 5.0  Amazon Prime Video            Android 11
# 3     Android TV 1st Generation            Sling TV     Android TV 12.3.2
# 4    Roku OS 9.4 3rd Generation                Voot                  None
# ..                          ...                 ...                   ...
# 995   Android TV 1st Generation             Peacock     Android TV 12.3.2
# 996  Roku OS 9.4 3rd Generation              Jio Tv                  None
# 997         All Fire TV devices    Disney + Hotstar        FireOS 7.6.1.3
# 998                Xbox One X/S             HBO Max            Windows 10
# 999               21TV_PREMIUM2            Sling TV         Extension 6.5
#
#                    country           state networkStrength  \
# 0            French Guiana         Cayenne
# 1             Cook Islands          Avarua
# 2                  Namibia        Windhoek
# 3                    Ghana           Accra
# 4             Saint Helena       Jamestown
# ..                     ...             ...             ...
# 995  Palestinian Territory  East Jerusalem
# 996             Micronesia         Palikir
# 997                 Jersey    Saint Helier
# 998             Bangladesh           Dhaka
# 999           Sint Maarten     Philipsburg
#
#                                 contentID Advertise /  Video
# 0    4ab493d3-1a0e-44fc-848c-c2bf2c860ba1              Video
# 1    79804eaf-9013-4970-ba2c-c5b1f3cdc932          Advertise
# 2    19296da5-f880-4dbc-89c9-0b639b0fdded          Advertise
# 3    32cb9812-971d-4177-9080-5618b2b1f373          Advertise
# 4    587e4560-8530-4621-bdd3-055b97f00531              Video
# ..                                    ...                ...
# 995  148d07f5-6c32-478a-8220-3d45335a0670          Advertise
# 996  1eca2acd-ce72-44d6-a95c-75f640f84057              Video
# 997  c443c034-4712-47ba-8f1e-b453d6c17c4c          Advertise
# 998  f7a2ed79-b0ab-4216-9d88-c198aa279505          Advertise
# 999  c091801d-1cd7-4b89-a116-5cae7afad026              Video
#
# [1000 rows x 18 columns]

# %%
users_training.columns
users_training
# Out:
#         profile_ID Contact_type         DOB                        Email  \
# 0         rsanchez        Email   6/10/2005       ldixson3h@engadget.com
# 1         karina10        Email   1/12/2005         rearngy40@sphinn.com
# 2       sethconrad        Email  10/30/1992         tbecom72@spotify.com
# 3          ewilson        Email   8/14/2015         elavalde9g@google.ru
# 4    evanvelasquez        Email   5/25/1992           dmencib1@cisco.com
# ..             ...          ...         ...                          ...
# 995       brandili     WhatsApp  12/14/2021              mcokee0@psu.edu
# 996      davidlowe     WhatsApp    4/1/1993        ctothex@google.com.hk
# 997   carrierivera     WhatsApp   9/30/2002       bmacevillyh3@prlog.org
# 998   ronniecoffey     WhatsApp   8/29/2002         lberrowhy@smh.com.au
# 999     kathleen63     WhatsApp   5/28/1989  vmogienh@huffingtonpost.com
#
#     First_Name       Gender Mobile_Number  Pack_ID  Start_Date    Status  ...  \
# 0        Leese       Female  391-447-5117   432281  10/28/2021  INACTIVE  ...
# 1      Rubetta       Female  777-570-1291   432300   2/10/2021  INACTIVE  ...
# 2         Tait         Male  901-892-5768   432410  10/30/2022    ACTIVE  ...
# 3      Eugenia       Female  711-627-9420   432496   1/14/2022    ACTIVE  ...
# 4        Devan       Female  902-541-3157   432553   1/21/2022  INACTIVE  ...
# ..         ...          ...           ...      ...         ...       ...  ...
# 995   Maryjane       Female  755-848-1351   432660   3/22/2022  INACTIVE  ...
# 996       Chic         Male  472-131-0900   432693   9/25/2021  INACTIVE  ...
# 997       Bili       Female  568-875-8493   432771  11/24/2021  INACTIVE  ...
# 998      Lilli       Female  380-420-0034   432802   1/21/2022    ACTIVE  ...
# 999     Verney  Genderqueer  192-265-1461   433001   7/24/2021    ACTIVE  ...
#
#     Zipcode         UserId      avg_dur num_devs  freq_used_dev Customer Id  \
# 0    665 33       rsanchez  1512.277778       18  Android Phone  2546-KZAAT
# 1    111721       karina10  1329.500000        8           iPad  2371-KFUOG
# 2       NaN     sethconrad  1478.166667       18      PC/Laptop  0188-GWFLE
# 3       NaN        ewilson  1118.133333       15      PC/Laptop  0289-IVARM
# 4       NaN  evanvelasquez  1557.428571       21         FireTV  7672-VFMXZ
# ..      ...            ...          ...      ...            ...         ...
# 995     NaN       brandili  1266.307692       13      PC/Laptop  7361-YPXFS
# 996     NaN      davidlowe  1199.000000       18         FireTV  3466-BYAVD
# 997    6340   carrierivera  1482.000000       17         FireTV  5652-MSDEY
# 998     NaN   ronniecoffey  1518.000000       30      PC/Laptop  9970-QBCDA
# 999     NaN     kathleen63   520.200000       15         FireTV  6513-EECDB
#
#     Billing Id  Subscription Type   Billing Type  Customer Longevity
# 0       432156           12 Months          Paytm            4 Years
# 1       432157            3 Months     NetBanking            2 Years
# 2       432158            6 Months     NetBanking            3 Years
# 3       432159           12 Months          Paytm            4 Years
# 4       432160           12 Months          Paytm            4 Years
# ..         ...                 ...            ...                ...
# 995     433151           12 Months          Paytm            4 Years
# 996     433152           12 Months          Paytm            4 Years
# 997     433153           12 Months          Paytm            4 Years
# 998     433154           12 Months          Paytm            4 Years
# 999     433155           12 Months          Paytm            4 Years
#
# [1000 rows x 25 columns]

# %%
complaints_df["deviceType"] = users_training["freq_used_dev"]

# %%
users_complaints_training = users_training.merge(complaints_df, left_on = 'freq_used_dev', right_on = "deviceType", how = 'left')

# %% [markdown]
# users_complaints_training.

# %%
contracts_df.columns
# Out:
# Index(['Unnamed: 0', ' Contract Id', 'Contract Description', 'Contract Amount',
#        'Contract Effective Date', 'Contract End Date', 'Currency Code',
#        'Contract Term', 'SLA Scheme Id', 'Customer Segment'],
#       dtype='object')
