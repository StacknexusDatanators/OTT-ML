# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
import pandas as pd
from datetime import datetime, timedelta

# %%
train_df = pd.read_csv("data/training_data(new).csv")
churn_df = pd.read_csv("data/churn.csv")
# Out:
# /home/kezia/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: DtypeWarning: Columns (22) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
train_df
# Out:
#         profile_ID        DOB Contact_type       Gender  Pack_ID  Start_Date  \
# 0         rsanchez  6/10/2005        Email       Female   432281  10/28/2021
# 1         rsanchez  6/10/2005        Email       Female   432281  10/28/2021
# 2         rsanchez  6/10/2005        Email       Female   432281  10/28/2021
# 3         rsanchez  6/10/2005        Email       Female   432281  10/28/2021
# 4         rsanchez  6/10/2005        Email       Female   432281  10/28/2021
# ...            ...        ...          ...          ...      ...         ...
# 332119  kathleen63  5/28/1989     WhatsApp  Genderqueer   433001   7/24/2021
# 332120  kathleen63  5/28/1989     WhatsApp  Genderqueer   433001   7/24/2021
# 332121  kathleen63  5/28/1989     WhatsApp  Genderqueer   433001   7/24/2021
# 332122  kathleen63  5/28/1989     WhatsApp  Genderqueer   433001   7/24/2021
# 332123  kathleen63  5/28/1989     WhatsApp  Genderqueer   433001   7/24/2021
#
#           Status Upgradable Validity_End Country  ... Subscription Type  \
# 0       INACTIVE        YES    12/5/2022   India  ...                12
# 1       INACTIVE        YES    12/5/2022   India  ...                12
# 2       INACTIVE        YES    12/5/2022   India  ...                12
# 3       INACTIVE        YES    12/5/2022   India  ...                12
# 4       INACTIVE        YES    12/5/2022   India  ...                12
# ...          ...        ...          ...     ...  ...               ...
# 332119    ACTIVE         NO   12/11/2022   India  ...                12
# 332120    ACTIVE         NO   12/11/2022   India  ...                12
# 332121    ACTIVE         NO   12/11/2022   India  ...                12
# 332122    ACTIVE         NO   12/11/2022   India  ...                12
# 332123    ACTIVE         NO   12/11/2022   India  ...                12
#
#         Billing Type  Customer Longevity Advertise /  Video  networkStrength  \
# 0              Paytm                   4              Video
# 1              Paytm                   4              Video
# 2              Paytm                   4              Video
# 3              Paytm                   4          Advertise
# 4              Paytm                   4              Video
# ...              ...                 ...                ...              ...
# 332119         Paytm                   4          Advertise
# 332120         Paytm                   4              Video
# 332121         Paytm                   4              Video
# 332122         Paytm                   4          Advertise
# 332123         Paytm                   4              Video
#
#                   appVersion          platform         cdn Contract Term  \
# 0       macOS Ventura 13.0.1        YouTube TV  Cloudfront     12 Months
# 1                 Windows 10  Disney + Hotstar  Cloudfront      3 Months
# 2       macOS Ventura 13.0.1           Sonyliv      Akamai       1 Month
# 3                 Xcode 14.1          Sling TV  Cloudfront       1 Month
# 4          Android TV 12.3.2           Sonyliv  Cloudfront      3 Months
# ...                      ...               ...         ...           ...
# 332119  macOS Ventura 13.0.1    Facebook Watch  Cloudfront           NaN
# 332120            Xcode 14.1           HBO Max      Akamai           NaN
# 332121                  None            Jio Tv  Cloudfront           NaN
# 332122        FireOS 7.6.1.3  Disney + Hotstar  Cloudfront           NaN
# 332123         Extension 6.5          Sling TV      Akamai           NaN
#
#        Contract Amount
# 0               1500.0
# 1                650.0
# 2                350.0
# 3                350.0
# 4                650.0
# ...                ...
# 332119             NaN
# 332120             NaN
# 332121             NaN
# 332122             NaN
# 332123             NaN
#
# [332124 rows x 24 columns]

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()
 
train_df['Gender']= label_encoder.fit_transform(train_df['Gender'])
label_encoder = preprocessing.LabelEncoder()
train_df['Status']= label_encoder.fit_transform(train_df['Status'])
label_encoder = preprocessing.LabelEncoder()
train_df['Upgradable']= label_encoder.fit_transform(train_df['Upgradable'])
label_encoder = preprocessing.LabelEncoder()
train_df['Country']= label_encoder.fit_transform(train_df['Country'])
label_encoder = preprocessing.LabelEncoder()
train_df['freq_used_dev']= label_encoder.fit_transform(train_df['freq_used_dev'])
label_encoder = preprocessing.LabelEncoder()
train_df['Subscription Type']= label_encoder.fit_transform(train_df['Subscription Type'])
label_encoder = preprocessing.LabelEncoder()
train_df['Billing Type']= label_encoder.fit_transform(train_df['Billing Type'])
label_encoder = preprocessing.LabelEncoder()
train_df['Contact_type']= label_encoder.fit_transform(train_df['Contact_type'])
label_encoder = preprocessing.LabelEncoder()
train_df['Customer Longevity']= label_encoder.fit_transform(train_df['Customer Longevity'])
label_encoder = preprocessing.LabelEncoder()
train_df['State']= label_encoder.fit_transform(train_df['State'])
label_encoder = preprocessing.LabelEncoder()
train_df['profile_ID']= label_encoder.fit_transform(train_df['profile_ID'])
label_encoder = preprocessing.LabelEncoder()
train_df['Advertise /  Video']= label_encoder.fit_transform(train_df['Advertise /  Video'])
label_encoder = preprocessing.LabelEncoder()
train_df['networkStrength']= label_encoder.fit_transform(train_df['networkStrength'])
label_encoder = preprocessing.LabelEncoder()
train_df['appVersion']= label_encoder.fit_transform(train_df['appVersion'])
label_encoder = preprocessing.LabelEncoder()
train_df['platform']= label_encoder.fit_transform(train_df['platform'])
label_encoder = preprocessing.LabelEncoder()
train_df['cdn']= label_encoder.fit_transform(train_df['cdn'])
label_encoder = preprocessing.LabelEncoder()

# %%
train_df
# Out:
#         profile_ID        DOB  Contact_type  Gender  Pack_ID  Start_Date  \
# 0              776  6/10/2005             0       2   432281  10/28/2021
# 1              776  6/10/2005             0       2   432281  10/28/2021
# 2              776  6/10/2005             0       2   432281  10/28/2021
# 3              776  6/10/2005             0       2   432281  10/28/2021
# 4              776  6/10/2005             0       2   432281  10/28/2021
# ...            ...        ...           ...     ...      ...         ...
# 332119         481  5/28/1989             3       4   433001   7/24/2021
# 332120         481  5/28/1989             3       4   433001   7/24/2021
# 332121         481  5/28/1989             3       4   433001   7/24/2021
# 332122         481  5/28/1989             3       4   433001   7/24/2021
# 332123         481  5/28/1989             3       4   433001   7/24/2021
#
#         Status  Upgradable Validity_End  Country  ...  Subscription Type  \
# 0            1           1    12/5/2022        0  ...                  3
# 1            1           1    12/5/2022        0  ...                  3
# 2            1           1    12/5/2022        0  ...                  3
# 3            1           1    12/5/2022        0  ...                  3
# 4            1           1    12/5/2022        0  ...                  3
# ...        ...         ...          ...      ...  ...                ...
# 332119       0           0   12/11/2022        0  ...                  3
# 332120       0           0   12/11/2022        0  ...                  3
# 332121       0           0   12/11/2022        0  ...                  3
# 332122       0           0   12/11/2022        0  ...                  3
# 332123       0           0   12/11/2022        0  ...                  3
#
#         Billing Type  Customer Longevity  Advertise /  Video  networkStrength  \
# 0                  1                   3                   1                0
# 1                  1                   3                   1                0
# 2                  1                   3                   1                0
# 3                  1                   3                   0                0
# 4                  1                   3                   1                0
# ...              ...                 ...                 ...              ...
# 332119             1                   3                   0                0
# 332120             1                   3                   1                0
# 332121             1                   3                   1                0
# 332122             1                   3                   0                0
# 332123             1                   3                   1                0
#
#         appVersion  platform  cdn  Contract Term  Contract Amount
# 0                7        17    1      12 Months           1500.0
# 1                5         4    1       3 Months            650.0
# 2                7        15    0        1 Month            350.0
# 3                6        14    1        1 Month            350.0
# 4                1        15    1       3 Months            650.0
# ...            ...       ...  ...            ...              ...
# 332119           7         6    1            NaN              NaN
# 332120           6         7    0            NaN              NaN
# 332121           4         9    1            NaN              NaN
# 332122           3         4    1            NaN              NaN
# 332123           2        14    0            NaN              NaN
#
# [332124 rows x 24 columns]

# %%
def  get_age(dob):
    diff = datetime.now()-dob
    return diff.days/365

# %%
train_df["DOB"] = pd.to_datetime(train_df["DOB"])
train_df["age"] = train_df["DOB"].apply(get_age)

# %%
train_df["Start_Date"] = pd.to_datetime(train_df["Start_Date"])
train_df["Validity_End"] = pd.to_datetime(train_df["Validity_End"])

# %%
train_df["val_period"] = train_df["Validity_End"] - train_df["Start_Date"]

# %%
train_df["val_period"] = train_df["val_period"].apply(lambda x: x.days/30 if x.days > 0. else 0.)

# %%
train_df["val_period"].describe()
# Out:
# count    332124.000000
# mean         11.773731
# std           6.536115
# min           0.000000
# 25%           6.400000
# 50%          11.600000
# 75%          17.166667
# max          24.166667
# Name: val_period, dtype: float64

# %%
train_df.head()
# Out:
#    profile_ID        DOB  Contact_type  Gender  Pack_ID Start_Date  Status  \
# 0         776 2005-06-10             0       2   432281 2021-10-28       1
# 1         776 2005-06-10             0       2   432281 2021-10-28       1
# 2         776 2005-06-10             0       2   432281 2021-10-28       1
# 3         776 2005-06-10             0       2   432281 2021-10-28       1
# 4         776 2005-06-10             0       2   432281 2021-10-28       1
#
#    Upgradable Validity_End  Country  ...  Customer Longevity  \
# 0           1   2022-12-05        0  ...                   3
# 1           1   2022-12-05        0  ...                   3
# 2           1   2022-12-05        0  ...                   3
# 3           1   2022-12-05        0  ...                   3
# 4           1   2022-12-05        0  ...                   3
#
#    Advertise /  Video  networkStrength  appVersion  platform  cdn  \
# 0                   1                0           7        17    1
# 1                   1                0           5         4    1
# 2                   1                0           7        15    0
# 3                   0                0           6        14    1
# 4                   1                0           1        15    1
#
#    Contract Term  Contract Amount        age  val_period
# 0      12 Months           1500.0  17.487671   13.433333
# 1       3 Months            650.0  17.487671   13.433333
# 2        1 Month            350.0  17.487671   13.433333
# 3        1 Month            350.0  17.487671   13.433333
# 4       3 Months            650.0  17.487671   13.433333
#
# [5 rows x 26 columns]

# %%
train_df.drop(['Start_Date'], axis=1, inplace= True)

train_df.drop(['Validity_End'], axis=1, inplace= True)

train_df.drop(['DOB'], axis=1, inplace= True)

# %%
train_df.head()
# Out:
#    profile_ID  Contact_type  Gender  Pack_ID  Status  Upgradable  Country  \
# 0         776             0       2   432281       1           1        0
# 1         776             0       2   432281       1           1        0
# 2         776             0       2   432281       1           1        0
# 3         776             0       2   432281       1           1        0
# 4         776             0       2   432281       1           1        0
#
#    State      avg_dur  num_devs  ...  Customer Longevity  Advertise /  Video  \
# 0      5  1512.277778        18  ...                   3                   1
# 1      5  1512.277778        18  ...                   3                   1
# 2      5  1512.277778        18  ...                   3                   1
# 3      5  1512.277778        18  ...                   3                   0
# 4      5  1512.277778        18  ...                   3                   1
#
#    networkStrength  appVersion  platform  cdn  Contract Term  Contract Amount  \
# 0                0           7        17    1      12 Months           1500.0
# 1                0           5         4    1       3 Months            650.0
# 2                0           7        15    0        1 Month            350.0
# 3                0           6        14    1        1 Month            350.0
# 4                0           1        15    1       3 Months            650.0
#
#          age val_period
# 0  17.487671  13.433333
# 1  17.487671  13.433333
# 2  17.487671  13.433333
# 3  17.487671  13.433333
# 4  17.487671  13.433333
#
# [5 rows x 23 columns]

# %%
churn_df = pd.read_csv("data/churn.csv")
churn_df.head()
# Out:
#   profile_ID  churn
# 0   rsanchez      0
# 1   rsanchez      0
# 2   rsanchez      1
# 3   rsanchez      1
# 4   rsanchez      1

# %%
cols2train = ['Contact_type', 'Gender', 'Pack_ID',
       'Status', 'Upgradable', 'State', 'avg_dur', 'num_devs',
       'freq_used_dev', 'Subscription Type', 'Billing Type',
       'Customer Longevity', 'age','val_period','cdn','platform','appVersion','networkStrength','Advertise /  Video'
]

# %%
X = train_df[cols2train]
y = churn_df["churn"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7)

# %%
lr_mod = LogisticRegression()

# %%
X_train
# Out:
#         Contact_type  Gender  Pack_ID  Status  Upgradable  State      avg_dur  \
# 230644             2       5   432998       1           0     27  1045.333333
# 70053              0       2   432571       0           0     25   980.250000
# 21909              0       1   432451       0           1      6  1787.368421
# 232626             2       2   432487       1           1      4  1033.333333
# 11284              0       5   432940       0           0     11   683.571429
# ...              ...     ...      ...     ...         ...    ...          ...
# 155470             1       5   432830       0           0     25  1597.277778
# 45925              0       4   432179       1           0     23  1162.136364
# 109302             1       5   433025       1           1     21  1047.235294
# 165267             1       5   432457       0           0     12  1432.440000
# 182139             2       5   432776       0           0     11  1270.222222
#
#         num_devs  freq_used_dev  Subscription Type  Billing Type  \
# 230644        18              3                  2             0
# 70053         20              3                  3             1
# 21909         19              3                  1             0
# 232626        42              4                  2             0
# 11284         14              3                  1             0
# ...          ...            ...                ...           ...
# 155470        18              4                  3             1
# 45925         22              4                  1             0
# 109302        17              4                  3             1
# 165267        25              3                  3             1
# 182139         9              3                  3             1
#
#         Customer Longevity        age  val_period  cdn  platform  appVersion  \
# 230644                   2  33.372603   20.966667    0        10           6
# 70053                    3  25.309589   14.133333    0        17           0
# 21909                    1   7.216438   22.700000    0         8           7
# 232626                   2   7.668493    2.066667    0        18           3
# 11284                    1  16.221918    1.533333    0         8           2
# ...                    ...        ...         ...  ...       ...         ...
# 155470                   3  24.172603   16.466667    0         2           3
# 45925                    1  36.923288   22.566667    1        10           3
# 109302                   3  33.232877   15.633333    1         6           6
# 165267                   3   7.208219    4.766667    0         0           6
# 182139                   3  20.616438   18.933333    0         9           4
#
#         networkStrength  Advertise /  Video
# 230644                0                   1
# 70053                 0                   1
# 21909                 0                   1
# 232626                0                   0
# 11284                 0                   1
# ...                 ...                 ...
# 155470                0                   1
# 45925                 0                   1
# 109302                0                   0
# 165267                0                   1
# 182139                0                   1
#
# [232486 rows x 19 columns]

# %%
lr_mod.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr_mod.score(X_test, y_test)
# Out:
# 0.801270599570445
