# %%
import pandas as pd
import numpy as np
from collections import Counter

# %%
player_df = pd.read_csv("file1.csv")
contracts_df = pd.read_csv("contracts.csv")
b2b_df = pd.read_csv("B2B Partner.csv")
complaints_df = pd.read_csv("complaints.csv")
billing_df = pd.read_csv("Billing 2.csv")
users_df = pd.read_csv("User Subscription Data - User Subscription Data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-297297050498> in <module>
# ----> 1 player_df = pd.read_csv("file1.csv")
#       2 contracts_df = pd.read_csv("contracts.csv")
#       3 b2b_df = pd.read_csv("B2B Partner.csv")
#       4 complaints_df = pd.read_csv("complaints.csv")
#       5 billing_df = pd.read_csv("Billing 2.csv")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file1.csv'

# %%
player_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8e2f26f71a30> in <module>
# ----> 1 player_df.head()
#
# NameError: name 'player_df' is not defined

# %%
contracts_df.columns

# %%
complaints_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-66dcbc38fbd1> in <module>
# ----> 1 complaints_df.columns
#
# NameError: name 'complaints_df' is not defined

# %%
contracts_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-479bad891446> in <module>
# ----> 1 contracts_df.head()
#
# NameError: name 'contracts_df' is not defined

# %%
complaints_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-bcbf0d0c2f5f> in <module>
# ----> 1 complaints_df.head()
#
# NameError: name 'complaints_df' is not defined

# %%
train_df = pd.read_csv("train_df.csv")

# %%
train_df
# Out:
#      Unnamed: 0     profile_ID         DOB Contact_type       Gender  Pack_ID  \
# 0             0       rsanchez   6/10/2005        Email       Female   432281
# 1             1       karina10   1/12/2005        Email       Female   432300
# 2             2     sethconrad  10/30/1992        Email         Male   432410
# 3             3        ewilson   8/14/2015        Email       Female   432496
# 4             4  evanvelasquez   5/25/1992        Email       Female   432553
# ..          ...            ...         ...          ...          ...      ...
# 995         995       brandili  12/14/2021     WhatsApp       Female   432660
# 996         996      davidlowe    4/1/1993     WhatsApp         Male   432693
# 997         997   carrierivera   9/30/2002     WhatsApp       Female   432771
# 998         998   ronniecoffey   8/29/2002     WhatsApp       Female   432802
# 999         999     kathleen63   5/28/1989     WhatsApp  Genderqueer   433001
#
#      Start_Date    Status Upgradable Validity_End Country              State  \
# 0    10/28/2021  INACTIVE        YES    12/5/2022   India                Goa
# 1     2/10/2021  INACTIVE         NO   11/22/2022   India                Goa
# 2    10/30/2022    ACTIVE        YES   11/10/2022   India                Goa
# 3     1/14/2022    ACTIVE         NO   12/27/2022   India                Goa
# 4     1/21/2022  INACTIVE        YES    11/9/2022   India                Goa
# ..          ...       ...        ...          ...     ...                ...
# 995   3/22/2022  INACTIVE         NO   12/26/2022   India  Arunachal Pradesh
# 996   9/25/2021  INACTIVE        YES   11/14/2022   India  Arunachal Pradesh
# 997  11/24/2021  INACTIVE        YES    12/3/2022   India  Arunachal Pradesh
# 998   1/21/2022    ACTIVE         NO   12/16/2022   India  Arunachal Pradesh
# 999   7/24/2021    ACTIVE         NO   12/11/2022   India  Arunachal Pradesh
#
#          avg_dur  num_devs  freq_used_dev  Subscription Type Billing Type  \
# 0    1512.277778        18  Android Phone                 12        Paytm
# 1    1329.500000         8           iPad                  3   NetBanking
# 2    1478.166667        18      PC/Laptop                  6   NetBanking
# 3    1118.133333        15      PC/Laptop                 12        Paytm
# 4    1557.428571        21         FireTV                 12        Paytm
# ..           ...       ...            ...                ...          ...
# 995  1266.307692        13      PC/Laptop                 12        Paytm
# 996  1199.000000        18         FireTV                 12        Paytm
# 997  1482.000000        17         FireTV                 12        Paytm
# 998  1518.000000        30      PC/Laptop                 12        Paytm
# 999   520.200000        15         FireTV                 12        Paytm
#
#      Customer Longevity
# 0                     4
# 1                     2
# 2                     3
# 3                     4
# 4                     4
# ..                  ...
# 995                   4
# 996                   4
# 997                   4
# 998                   4
# 999                   4
#
# [1000 rows x 18 columns]

# %%
users_df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9b0551ae842f> in <module>
# ----> 1 users_df()
#
# NameError: name 'users_df' is not defined

# %%
train_df = train_df.merge(contracts_df, on = "Unnamed: 0", how = "left")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-44e50adcaed6> in <module>
# ----> 1 train_df = train_df.merge(contracts_df, on = "Unnamed: 0", how = "left")
#
# NameError: name 'contracts_df' is not defined

# %%
train_df
# Out:
#      Unnamed: 0     profile_ID         DOB Contact_type       Gender  Pack_ID  \
# 0             0       rsanchez   6/10/2005        Email       Female   432281
# 1             1       karina10   1/12/2005        Email       Female   432300
# 2             2     sethconrad  10/30/1992        Email         Male   432410
# 3             3        ewilson   8/14/2015        Email       Female   432496
# 4             4  evanvelasquez   5/25/1992        Email       Female   432553
# ..          ...            ...         ...          ...          ...      ...
# 995         995       brandili  12/14/2021     WhatsApp       Female   432660
# 996         996      davidlowe    4/1/1993     WhatsApp         Male   432693
# 997         997   carrierivera   9/30/2002     WhatsApp       Female   432771
# 998         998   ronniecoffey   8/29/2002     WhatsApp       Female   432802
# 999         999     kathleen63   5/28/1989     WhatsApp  Genderqueer   433001
#
#      Start_Date    Status Upgradable Validity_End  ... Customer Longevity  \
# 0    10/28/2021  INACTIVE        YES    12/5/2022  ...                  4
# 1     2/10/2021  INACTIVE         NO   11/22/2022  ...                  2
# 2    10/30/2022    ACTIVE        YES   11/10/2022  ...                  3
# 3     1/14/2022    ACTIVE         NO   12/27/2022  ...                  4
# 4     1/21/2022  INACTIVE        YES    11/9/2022  ...                  4
# ..          ...       ...        ...          ...  ...                ...
# 995   3/22/2022  INACTIVE         NO   12/26/2022  ...                  4
# 996   9/25/2021  INACTIVE        YES   11/14/2022  ...                  4
# 997  11/24/2021  INACTIVE        YES    12/3/2022  ...                  4
# 998   1/21/2022    ACTIVE         NO   12/16/2022  ...                  4
# 999   7/24/2021    ACTIVE         NO   12/11/2022  ...                  4
#
#      Contract Id                               Contract Description  \
# 0     32-8540983  sit amet justo morbi ut odio cras mi pede male...
# 1     25-9229010  est lacinia nisi venenatis tristique fusce con...
# 2     78-7194379  vestibulum ante ipsum primis in faucibus orci ...
# 3     76-2104357  platea dictumst morbi vestibulum velit id pret...
# 4     98-2263265  feugiat et eros vestibulum ac est lacinia nisi...
# ..           ...                                                ...
# 995   71-0228805  nisi eu orci mauris lacinia sapien quis libero...
# 996   15-9310366  posuere cubilia curae nulla dapibus dolor vel ...
# 997   49-1354785  cubilia curae donec pharetra magna vestibulum ...
# 998   71-0828876  quam sapien varius ut blandit non interdum in ...
# 999   69-8294975  nulla nunc purus phasellus in felis donec semp...
#
#      Contract Amount Contract Effective Date  Contract End Date Currency Code  \
# 0               1500              22-11-2019         31-08-2020           INR
# 1                650              26-08-2019         18-06-2020           INR
# 2                350              02-05-2021         02-08-2021           INR
# 3                350              27-11-2020         30-08-2023           INR
# 4                650              27-10-2021         24-07-2022           INR
# ..               ...                     ...                ...           ...
# 995             1500              12-04-2022         22-08-2021           INR
# 996              650              09-06-2020         19-08-2020           INR
# 997              350              21-06-2020         02-01-2022           INR
# 998             1500              09-05-2019         01-01-2021           INR
# 999              650              19-06-2020         02-01-2023           INR
#
#      Contract Term SLA Scheme Id Customer Segment
# 0        12 Months       #26db3a            Empty
# 1         3 Months       #0344fe            Empty
# 2          1 Month       #b3409b            Empty
# 3          1 Month       #a6dcb3            Empty
# 4         3 Months       #5dcc6e            Empty
# ..             ...           ...              ...
# 995      12 Months       #c0378c            Empty
# 996       3 Months       #93853a            Empty
# 997        1 Month       #e0b4f8            Empty
# 998      12 Months       #ffacbc            Empty
# 999       3 Months       #250be5            Empty
#
# [1000 rows x 27 columns]

# %%
train_df = train_df.merge(complaints_df,on = 'Unnamed: 0', how = 'left')

# %%
train_df
# Out:
#      Unnamed: 0     profile_ID         DOB Contact_type       Gender  Pack_ID  \
# 0             0       rsanchez   6/10/2005        Email       Female   432281
# 1             1       karina10   1/12/2005        Email       Female   432300
# 2             2     sethconrad  10/30/1992        Email         Male   432410
# 3             3        ewilson   8/14/2015        Email       Female   432496
# 4             4  evanvelasquez   5/25/1992        Email       Female   432553
# ..          ...            ...         ...          ...          ...      ...
# 995         995       brandili  12/14/2021     WhatsApp       Female   432660
# 996         996      davidlowe    4/1/1993     WhatsApp         Male   432693
# 997         997   carrierivera   9/30/2002     WhatsApp       Female   432771
# 998         998   ronniecoffey   8/29/2002     WhatsApp       Female   432802
# 999         999     kathleen63   5/28/1989     WhatsApp  Genderqueer   433001
#
#      Start_Date    Status Upgradable Validity_End  ...  \
# 0    10/28/2021  INACTIVE        YES    12/5/2022  ...
# 1     2/10/2021  INACTIVE         NO   11/22/2022  ...
# 2    10/30/2022    ACTIVE        YES   11/10/2022  ...
# 3     1/14/2022    ACTIVE         NO   12/27/2022  ...
# 4     1/21/2022  INACTIVE        YES    11/9/2022  ...
# ..          ...       ...        ...          ...  ...
# 995   3/22/2022  INACTIVE         NO   12/26/2022  ...
# 996   9/25/2021  INACTIVE        YES   11/14/2022  ...
# 997  11/24/2021  INACTIVE        YES    12/3/2022  ...
# 998   1/21/2022    ACTIVE         NO   12/16/2022  ...
# 999   7/24/2021    ACTIVE         NO   12/11/2022  ...
#
#                            userIdentifier                     deviceDetails  \
# 0    33824779-a665-4ba5-b3d0-0de8228e107d                               iOS
# 1    f057f978-2bcf-4280-a52b-9045aed4f0fa                              tvOS
# 2    7e20a079-a408-4f3e-b955-aa4bf1a57920                           Android
# 3    9f6559ce-efb1-4008-a516-eb71010029df                        Android TV
# 4    e96a1649-4bf3-4533-a696-d304b2882ca5                              Roku
# ..                                    ...                               ...
# 995  1d63557f-57e3-487d-a6a1-c540654600be                        Android TV
# 996  528450d5-63ed-4d8b-99f2-37c8097ff862                              Roku
# 997  8bf95aef-a255-4996-af58-5a1d8ad618bb                    Amazon Fire TV
# 998  0a29b7db-a8bf-4637-a3e5-d15f48d099c8  Universal Windows Platform (UWP)
# 999  ef7b836e-4e26-42aa-9543-3059a112e3f6                  Samsung Tizen TV
#
#                       OSDetails            platform            appVersion  \
# 0          iOS Min version 12.6          YouTube TV  macOS Ventura 13.0.1
# 1                     tvOS 11.0             BigFlix            Xcode 14.1
# 2                   Android 5.0  Amazon Prime Video            Android 11
# 3     Android TV 1st Generation            Sling TV     Android TV 12.3.2
# 4    Roku OS 9.4 3rd Generation                Voot                  None
# ..                          ...                 ...                   ...
# 995   Android TV 1st Generation             Peacock     Android TV 12.3.2
# 996  Roku OS 9.4 3rd Generation              Jio Tv                  None
# 997         All Fire TV devices    Disney + Hotstar        FireOS 7.6.1.3
# 998                Xbox One X/S             HBO Max            Windows 10
# 999               21TV_PREMIUM2            Sling TV         Extension 6.5
#
#                    country           state  networkStrength  \
# 0            French Guiana         Cayenne              NaN
# 1             Cook Islands          Avarua              NaN
# 2                  Namibia        Windhoek              NaN
# 3                    Ghana           Accra              NaN
# 4             Saint Helena       Jamestown              NaN
# ..                     ...             ...              ...
# 995  Palestinian Territory  East Jerusalem              NaN
# 996             Micronesia         Palikir              NaN
# 997                 Jersey    Saint Helier              NaN
# 998             Bangladesh           Dhaka              NaN
# 999           Sint Maarten     Philipsburg              NaN
#
#                                 contentID Advertise /  Video
# 0    4ab493d3-1a0e-44fc-848c-c2bf2c860ba1              Video
# 1    79804eaf-9013-4970-ba2c-c5b1f3cdc932          Advertise
# 2    19296da5-f880-4dbc-89c9-0b639b0fdded          Advertise
# 3    32cb9812-971d-4177-9080-5618b2b1f373          Advertise
# 4    587e4560-8530-4621-bdd3-055b97f00531              Video
# ..                                    ...                ...
# 995  148d07f5-6c32-478a-8220-3d45335a0670          Advertise
# 996  1eca2acd-ce72-44d6-a95c-75f640f84057              Video
# 997  c443c034-4712-47ba-8f1e-b453d6c17c4c          Advertise
# 998  f7a2ed79-b0ab-4216-9d88-c198aa279505          Advertise
# 999  c091801d-1cd7-4b89-a116-5cae7afad026              Video
#
# [1000 rows x 45 columns]

# %%
#merging the complaints file in the training data
complaints_df.head(3)
# Out:
#                   IssueType deviceType   IssueTime  \
# 0  Security and anti-piracy    Desktop  27-03-2022
# 1  Security and anti-piracy    Tablets  10-05-2022
# 2    Multiple user accounts         TV  27-07-2022
#
#                                         IssueDetails  mobileNumber  \
# 0  potenti nullam porttitor lacus at turpis donec...    4016190347
# 1  vel accumsan tellus nisi eu orci mauris lacini...     146998510
# 2  in sagittis dui vel nisl duis ac nibh fusce la...    9928344523
#
#                  emailId        mode         cdn  \
# 0       ggrono0@yale.edu       Email  Cloudfront
# 1       acann1@vimeo.com  Phone Call  Cloudfront
# 2  fdizlie2@mashable.com  Phone Call  Cloudfront
#
#                          userIdentifier deviceDetails             OSDetails  \
# 0  33824779-a665-4ba5-b3d0-0de8228e107d           iOS  iOS Min version 12.6
# 1  f057f978-2bcf-4280-a52b-9045aed4f0fa          tvOS             tvOS 11.0
# 2  7e20a079-a408-4f3e-b955-aa4bf1a57920       Android           Android 5.0
#
#              platform            appVersion        country     state  \
# 0          YouTube TV  macOS Ventura 13.0.1  French Guiana   Cayenne
# 1             BigFlix            Xcode 14.1   Cook Islands    Avarua
# 2  Amazon Prime Video            Android 11        Namibia  Windhoek
#
#    networkStrength                             contentID Advertise /  Video
# 0              NaN  4ab493d3-1a0e-44fc-848c-c2bf2c860ba1              Video
# 1              NaN  79804eaf-9013-4970-ba2c-c5b1f3cdc932          Advertise
# 2              NaN  19296da5-f880-4dbc-89c9-0b639b0fdded          Advertise

# %%
#droping some columns from the compalint dataframe
complaints_df.drop(['IssueDetails', 'mobileNumber','emailId','cdn','userIdentifier','deviceDetails','country','state','networkStrength','contentID','Advertise /  Video'], axis=1, inplace= True)

# %%
complaints_df.head()
# Out:
#                                  IssueType deviceType   IssueTime        mode  \
# 0                 Security and anti-piracy    Desktop  27-03-2022       Email
# 1                 Security and anti-piracy    Tablets  10-05-2022  Phone Call
# 2                   Multiple user accounts         TV  27-07-2022  Phone Call
# 3                         Playback Quality    Desktop  26-07-2022  Phone Call
# 4  Functionalities and features of the app    Desktop  03-02-2022        Chat
#
#                     OSDetails            platform            appVersion
# 0        iOS Min version 12.6          YouTube TV  macOS Ventura 13.0.1
# 1                   tvOS 11.0             BigFlix            Xcode 14.1
# 2                 Android 5.0  Amazon Prime Video            Android 11
# 3   Android TV 1st Generation            Sling TV     Android TV 12.3.2
# 4  Roku OS 9.4 3rd Generation                Voot                  None

# %%
#changing the name of some feature
complaints_df.rename(columns = {'deviceType':'IssueDeviceType','mode':'modeofcomplaint'}, inplace = True)

# %%
complaints_df.head()
# Out:
#                                  IssueType IssueDeviceType   IssueTime  \
# 0                 Security and anti-piracy         Desktop  27-03-2022
# 1                 Security and anti-piracy         Tablets  10-05-2022
# 2                   Multiple user accounts              TV  27-07-2022
# 3                         Playback Quality         Desktop  26-07-2022
# 4  Functionalities and features of the app         Desktop  03-02-2022
#
#   modeofcomplaint                   OSDetails            platform  \
# 0           Email        iOS Min version 12.6          YouTube TV
# 1      Phone Call                   tvOS 11.0             BigFlix
# 2      Phone Call                 Android 5.0  Amazon Prime Video
# 3      Phone Call   Android TV 1st Generation            Sling TV
# 4            Chat  Roku OS 9.4 3rd Generation                Voot
#
#              appVersion
# 0  macOS Ventura 13.0.1
# 1            Xcode 14.1
# 2            Android 11
# 3     Android TV 12.3.2
# 4                  None

# %%
train_df = pd.concat([train_df, complaints_df], axis=1, join='inner')
train_df
# Out:
#      Unnamed: 0     profile_ID         DOB Contact_type       Gender  Pack_ID  \
# 0             0       rsanchez   6/10/2005        Email       Female   432281
# 1             1       karina10   1/12/2005        Email       Female   432300
# 2             2     sethconrad  10/30/1992        Email         Male   432410
# 3             3        ewilson   8/14/2015        Email       Female   432496
# 4             4  evanvelasquez   5/25/1992        Email       Female   432553
# ..          ...            ...         ...          ...          ...      ...
# 995         995       brandili  12/14/2021     WhatsApp       Female   432660
# 996         996      davidlowe    4/1/1993     WhatsApp         Male   432693
# 997         997   carrierivera   9/30/2002     WhatsApp       Female   432771
# 998         998   ronniecoffey   8/29/2002     WhatsApp       Female   432802
# 999         999     kathleen63   5/28/1989     WhatsApp  Genderqueer   433001
#
#      Start_Date    Status Upgradable Validity_End  ... Subscription Type  \
# 0    10/28/2021  INACTIVE        YES    12/5/2022  ...                12
# 1     2/10/2021  INACTIVE         NO   11/22/2022  ...                 3
# 2    10/30/2022    ACTIVE        YES   11/10/2022  ...                 6
# 3     1/14/2022    ACTIVE         NO   12/27/2022  ...                12
# 4     1/21/2022  INACTIVE        YES    11/9/2022  ...                12
# ..          ...       ...        ...          ...  ...               ...
# 995   3/22/2022  INACTIVE         NO   12/26/2022  ...                12
# 996   9/25/2021  INACTIVE        YES   11/14/2022  ...                12
# 997  11/24/2021  INACTIVE        YES    12/3/2022  ...                12
# 998   1/21/2022    ACTIVE         NO   12/16/2022  ...                12
# 999   7/24/2021    ACTIVE         NO   12/11/2022  ...                12
#
#     Billing Type  Customer Longevity                                IssueType  \
# 0          Paytm                   4                 Security and anti-piracy
# 1     NetBanking                   2                 Security and anti-piracy
# 2     NetBanking                   3                   Multiple user accounts
# 3          Paytm                   4                         Playback Quality
# 4          Paytm                   4  Functionalities and features of the app
# ..           ...                 ...                                      ...
# 995        Paytm                   4                         Playback Quality
# 996        Paytm                   4      Response Time in different networks
# 997        Paytm                   4                          Offline content
# 998        Paytm                   4      Response Time in different networks
# 999        Paytm                   4      Response Time in different networks
#
#     IssueDeviceType   IssueTime modeofcomplaint                   OSDetails  \
# 0           Desktop  27-03-2022           Email        iOS Min version 12.6
# 1           Tablets  10-05-2022      Phone Call                   tvOS 11.0
# 2                TV  27-07-2022      Phone Call                 Android 5.0
# 3           Desktop  26-07-2022      Phone Call   Android TV 1st Generation
# 4           Desktop  03-02-2022            Chat  Roku OS 9.4 3rd Generation
# ..              ...         ...             ...                         ...
# 995              TV  12-10-2022           Email   Android TV 1st Generation
# 996          Laptop  27-10-2022      Phone Call  Roku OS 9.4 3rd Generation
# 997          Mobile  10-05-2022           Email         All Fire TV devices
# 998          Laptop  04-06-2022           Email                Xbox One X/S
# 999         Tablets  08-03-2022           Email               21TV_PREMIUM2
#
#                platform            appVersion
# 0            YouTube TV  macOS Ventura 13.0.1
# 1               BigFlix            Xcode 14.1
# 2    Amazon Prime Video            Android 11
# 3              Sling TV     Android TV 12.3.2
# 4                  Voot                  None
# ..                  ...                   ...
# 995             Peacock     Android TV 12.3.2
# 996              Jio Tv                  None
# 997    Disney + Hotstar        FireOS 7.6.1.3
# 998             HBO Max            Windows 10
# 999            Sling TV         Extension 6.5
#
# [1000 rows x 25 columns]

# %%
#merging the Contracts file in the training data
contracts_df.head(3)
# Out:
#    Unnamed: 0  Contract Id                               Contract Description  \
# 0           0   32-8540983  sit amet justo morbi ut odio cras mi pede male...
# 1           1   25-9229010  est lacinia nisi venenatis tristique fusce con...
# 2           2   78-7194379  vestibulum ante ipsum primis in faucibus orci ...
#
#    Contract Amount Contract Effective Date Contract End Date Currency Code  \
# 0             1500              22-11-2019        31-08-2020           INR
# 1              650              26-08-2019        18-06-2020           INR
# 2              350              02-05-2021        02-08-2021           INR
#
#   Contract Term SLA Scheme Id Customer Segment
# 0     12 Months       #26db3a            Empty
# 1      3 Months       #0344fe            Empty
# 2       1 Month       #b3409b            Empty

# %%
#droping some columns from the compalint dataframe
contracts_df.drop(['Contract Description', 'Contract Description','Contract Term','SLA Scheme Id','Customer Segment','Contract End Date','Unnamed: 0'], axis=1, inplace= True)
# we are dropping "contract term" because its same as "supcription Type" in train_df
# we are dropping "Contract End Date" because its same as"validity_end" in train_df

# %%
contracts_df.head(3)
# Out:
#    Contract Id  Contract Amount Contract Effective Date Currency Code
# 0   32-8540983             1500              22-11-2019           INR
# 1   25-9229010              650              26-08-2019           INR
# 2   78-7194379              350              02-05-2021           INR

# %%
train_df = pd.concat([train_df, contracts_df], axis=1, join='inner')
train_df
# Out:
#      Unnamed: 0     profile_ID         DOB Contact_type       Gender  Pack_ID  \
# 0             0       rsanchez   6/10/2005        Email       Female   432281
# 1             1       karina10   1/12/2005        Email       Female   432300
# 2             2     sethconrad  10/30/1992        Email         Male   432410
# 3             3        ewilson   8/14/2015        Email       Female   432496
# 4             4  evanvelasquez   5/25/1992        Email       Female   432553
# ..          ...            ...         ...          ...          ...      ...
# 995         995       brandili  12/14/2021     WhatsApp       Female   432660
# 996         996      davidlowe    4/1/1993     WhatsApp         Male   432693
# 997         997   carrierivera   9/30/2002     WhatsApp       Female   432771
# 998         998   ronniecoffey   8/29/2002     WhatsApp       Female   432802
# 999         999     kathleen63   5/28/1989     WhatsApp  Genderqueer   433001
#
#      Start_Date    Status Upgradable Validity_End  ... IssueDeviceType  \
# 0    10/28/2021  INACTIVE        YES    12/5/2022  ...         Desktop
# 1     2/10/2021  INACTIVE         NO   11/22/2022  ...         Tablets
# 2    10/30/2022    ACTIVE        YES   11/10/2022  ...              TV
# 3     1/14/2022    ACTIVE         NO   12/27/2022  ...         Desktop
# 4     1/21/2022  INACTIVE        YES    11/9/2022  ...         Desktop
# ..          ...       ...        ...          ...  ...             ...
# 995   3/22/2022  INACTIVE         NO   12/26/2022  ...              TV
# 996   9/25/2021  INACTIVE        YES   11/14/2022  ...          Laptop
# 997  11/24/2021  INACTIVE        YES    12/3/2022  ...          Mobile
# 998   1/21/2022    ACTIVE         NO   12/16/2022  ...          Laptop
# 999   7/24/2021    ACTIVE         NO   12/11/2022  ...         Tablets
#
#       IssueTime  modeofcomplaint                   OSDetails  \
# 0    27-03-2022            Email        iOS Min version 12.6
# 1    10-05-2022       Phone Call                   tvOS 11.0
# 2    27-07-2022       Phone Call                 Android 5.0
# 3    26-07-2022       Phone Call   Android TV 1st Generation
# 4    03-02-2022             Chat  Roku OS 9.4 3rd Generation
# ..          ...              ...                         ...
# 995  12-10-2022            Email   Android TV 1st Generation
# 996  27-10-2022       Phone Call  Roku OS 9.4 3rd Generation
# 997  10-05-2022            Email         All Fire TV devices
# 998  04-06-2022            Email                Xbox One X/S
# 999  08-03-2022            Email               21TV_PREMIUM2
#
#                platform            appVersion  Contract Id  Contract Amount  \
# 0            YouTube TV  macOS Ventura 13.0.1   32-8540983             1500
# 1               BigFlix            Xcode 14.1   25-9229010              650
# 2    Amazon Prime Video            Android 11   78-7194379              350
# 3              Sling TV     Android TV 12.3.2   76-2104357              350
# 4                  Voot                  None   98-2263265              650
# ..                  ...                   ...          ...              ...
# 995             Peacock     Android TV 12.3.2   71-0228805             1500
# 996              Jio Tv                  None   15-9310366              650
# 997    Disney + Hotstar        FireOS 7.6.1.3   49-1354785              350
# 998             HBO Max            Windows 10   71-0828876             1500
# 999            Sling TV         Extension 6.5   69-8294975              650
#
#     Contract Effective Date Currency Code
# 0                22-11-2019           INR
# 1                26-08-2019           INR
# 2                02-05-2021           INR
# 3                27-11-2020           INR
# 4                27-10-2021           INR
# ..                      ...           ...
# 995              12-04-2022           INR
# 996              09-06-2020           INR
# 997              21-06-2020           INR
# 998              09-05-2019           INR
# 999              19-06-2020           INR
#
# [1000 rows x 29 columns]

# %%
train_df.drop(['Unnamed: 0'], axis=1, inplace= True)

# %%
train_df
# Out:
#         profile_ID         DOB Contact_type       Gender  Pack_ID  Start_Date  \
# 0         rsanchez   6/10/2005        Email       Female   432281  10/28/2021
# 1         karina10   1/12/2005        Email       Female   432300   2/10/2021
# 2       sethconrad  10/30/1992        Email         Male   432410  10/30/2022
# 3          ewilson   8/14/2015        Email       Female   432496   1/14/2022
# 4    evanvelasquez   5/25/1992        Email       Female   432553   1/21/2022
# ..             ...         ...          ...          ...      ...         ...
# 995       brandili  12/14/2021     WhatsApp       Female   432660   3/22/2022
# 996      davidlowe    4/1/1993     WhatsApp         Male   432693   9/25/2021
# 997   carrierivera   9/30/2002     WhatsApp       Female   432771  11/24/2021
# 998   ronniecoffey   8/29/2002     WhatsApp       Female   432802   1/21/2022
# 999     kathleen63   5/28/1989     WhatsApp  Genderqueer   433001   7/24/2021
#
#        Status Upgradable Validity_End Country  ... IssueDeviceType  \
# 0    INACTIVE        YES    12/5/2022   India  ...         Desktop
# 1    INACTIVE         NO   11/22/2022   India  ...         Tablets
# 2      ACTIVE        YES   11/10/2022   India  ...              TV
# 3      ACTIVE         NO   12/27/2022   India  ...         Desktop
# 4    INACTIVE        YES    11/9/2022   India  ...         Desktop
# ..        ...        ...          ...     ...  ...             ...
# 995  INACTIVE         NO   12/26/2022   India  ...              TV
# 996  INACTIVE        YES   11/14/2022   India  ...          Laptop
# 997  INACTIVE        YES    12/3/2022   India  ...          Mobile
# 998    ACTIVE         NO   12/16/2022   India  ...          Laptop
# 999    ACTIVE         NO   12/11/2022   India  ...         Tablets
#
#       IssueTime  modeofcomplaint                   OSDetails  \
# 0    27-03-2022            Email        iOS Min version 12.6
# 1    10-05-2022       Phone Call                   tvOS 11.0
# 2    27-07-2022       Phone Call                 Android 5.0
# 3    26-07-2022       Phone Call   Android TV 1st Generation
# 4    03-02-2022             Chat  Roku OS 9.4 3rd Generation
# ..          ...              ...                         ...
# 995  12-10-2022            Email   Android TV 1st Generation
# 996  27-10-2022       Phone Call  Roku OS 9.4 3rd Generation
# 997  10-05-2022            Email         All Fire TV devices
# 998  04-06-2022            Email                Xbox One X/S
# 999  08-03-2022            Email               21TV_PREMIUM2
#
#                platform            appVersion   Contract Id Contract Amount  \
# 0            YouTube TV  macOS Ventura 13.0.1    32-8540983            1500
# 1               BigFlix            Xcode 14.1    25-9229010             650
# 2    Amazon Prime Video            Android 11    78-7194379             350
# 3              Sling TV     Android TV 12.3.2    76-2104357             350
# 4                  Voot                  None    98-2263265             650
# ..                  ...                   ...           ...             ...
# 995             Peacock     Android TV 12.3.2    71-0228805            1500
# 996              Jio Tv                  None    15-9310366             650
# 997    Disney + Hotstar        FireOS 7.6.1.3    49-1354785             350
# 998             HBO Max            Windows 10    71-0828876            1500
# 999            Sling TV         Extension 6.5    69-8294975             650
#
#     Contract Effective Date Currency Code
# 0                22-11-2019           INR
# 1                26-08-2019           INR
# 2                02-05-2021           INR
# 3                27-11-2020           INR
# 4                27-10-2021           INR
# ..                      ...           ...
# 995              12-04-2022           INR
# 996              09-06-2020           INR
# 997              21-06-2020           INR
# 998              09-05-2019           INR
# 999              19-06-2020           INR
#
# [1000 rows x 28 columns]

# %%
train_df.to_csv("train_df.csv", index = False)
